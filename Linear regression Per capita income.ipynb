# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("canada_per_capita_income.csv")

df
# Out:
#    year\tper capita income (US$)
# 0              1970\t3399.299037
# 1              1971\t3768.297935
# 2              1972\t4251.175484
# 3              1973\t4804.463248
# 4              1974\t5576.514583
# 5              1975\t5998.144346
# 6              1976\t7062.131392
# 7               1977\t7100.12617
# 8              1978\t7247.967035
# 9              1979\t7602.912681
# 10              1980\t8355.96812
# 11             1981\t9434.390652
# 12             1982\t9619.438377
# 13             1983\t10416.53659
# 14             1984\t10790.32872
# 15             1985\t11018.95585
# 16             1986\t11482.89153
# 17             1987\t12974.80662
# 18             1988\t15080.28345
# 19             1989\t16426.72548
# 20              1990\t16838.6732
# 21             1991\t17266.09769
# 22             1992\t16412.08309
# 23             1993\t15875.58673
# 24             1994\t15755.82027
# 25             1995\t16369.31725
# 26             1996\t16699.82668
# 27             1997\t17310.75775
# 28             1998\t16622.67187
# 29             1999\t17581.02414
# 30             2000\t18987.38241
# 31             2001\t18601.39724
# 32             2002\t19232.17556
# 33             2003\t22739.42628
# 34             2004\t25719.14715
# 35             2005\t29198.05569
# 36              2006\t32738.2629
# 37             2007\t36144.48122
# 38             2008\t37446.48609
# 39             2009\t32755.17682
# 40             2010\t38420.52289
# 41             2011\t42334.71121
# 42             2012\t42665.25597
# 43             2013\t42676.46837
# 44              2014\t41039.8936
# 45             2015\t35175.18898
# 46             2016\t34229.19363

# %%
df=pd.read_csv("canada_per_capita_income.csv")

df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# 26  1996             16699.826680
# 27  1997             17310.757750
# 28  1998             16622.671870
# 29  1999             17581.024140
# 30  2000             18987.382410
# 31  2001             18601.397240
# 32  2002             19232.175560
# 33  2003             22739.426280
# 34  2004             25719.147150
# 35  2005             29198.055690
# 36  2006             32738.262900
# 37  2007             36144.481220
# 38  2008             37446.486090
# 39  2009             32755.176820
# 40  2010             38420.522890
# 41  2011             42334.711210
# 42  2012             42665.255970
# 43  2013             42676.468370
# 44  2014             41039.893600
# 45  2015             35175.188980
# 46  2016             34229.193630

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df.per_cap_income)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8bdb2b658436> in <module>
#       2 plt.xlabel('year')
#       3 plt.ylabel('per capita income (US$)')
# ----> 4 plt.scatter(df.year,df.per_cap_income)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'per_cap_income'

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
df = df.rename(columns={'per capita income (US$)': 'income'})

# %%
df.columns
# Out:
# Index(['year', 'income'], dtype='object')

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df.income,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f3d848d4a2aa> in <module>
#       1 reg=linear_model.LinearRegression()
# ----> 2 reg.fit(new_df,income)
#
# NameError: name 'new_df' is not defined

# %%
new_df = df.drop('income',axis='columns')
new_df
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
income=df.income
income
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# Name: income, dtype: float64

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
reg=linear_model.LinearRegression()
reg.fit(year,income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0c88b0c51dfe> in <module>
#       1 reg=linear_model.LinearRegression()
# ----> 2 reg.fit(year,income)
#
# NameError: name 'year' is not defined

# %%
reg.coef_,reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-31b8627d9b7a> in <module>
# ----> 1 reg.coef_,reg.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
reg.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a61ebb4c7cdc> in <module>
# ----> 1 reg.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
income_df = pd.read_csv("year_income.csv")
income_df.head(3)
# Out:
#    year
# 0  2017
# 1  2018
# 2  2019

# %%
p = reg.predict(income_df)
p
# Out:
# array([38803.29886875, 39631.76394397, 40460.22901919, 41288.69409442,
#        42117.15916964, 42945.62424486])
